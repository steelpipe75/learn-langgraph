# %% [markdown]
# <a href="https://colab.research.google.com/github/steelpipe75/learn-langgraph/blob/main/LangGraph/LangGraph%E3%81%A7%E3%81%97%E3%82%8A%E3%81%A8%E3%82%8A/LangGraph_shiritori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LangGraphでしりとり

# %% [markdown]
# ----

# %% [markdown]
# ライブラリをインストール

# %%
# !apt-get update
# !apt-get install -y graphviz libgraphviz-dev
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,078 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,780 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,263 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,098 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,752 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,566 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,410 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,933 kB]
# Fetched 31.3 MB in 5s (5,844 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk librsvg2-common libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgvc6-plugins-gtk librsvg2-common libxdot4
# 0 upgraded, 9 newly installed, 0 to remove and 51 not upgraded.
# Need to get 2,434 kB of archives.
# After this operation, 7,681 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libxdot4 amd64 2.42.2-6ubuntu0.1 [16.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgvc6-plugins-gtk amd64 2.42.2-6ubuntu0.1 [22.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgraphviz-dev amd64 2.42.2-6ubuntu0.1 [58.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Fetched 2,434 kB in 2s (1,616 kB/s)
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6ubuntu0.1_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../8-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libxdot4:amd64 (2.42.2-6ubuntu0.1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6ubuntu0.1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6ubuntu0.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...

# %%
# !pip install langgraph pygraphviz
# Out:
# Collecting langgraph
#   Downloading langgraph-0.5.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting pygraphviz
#   Downloading pygraphviz-1.14.tar.gz (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.3.67)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.1.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.6.0,>=0.5.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph)
#   Downloading langgraph_sdk-0.1.72-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langgraph) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (3.5.0)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (4.14.0)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.18)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core>=0.1->langgraph) (2.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Downloading langgraph-0.5.1-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 10.3 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.1.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.7 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl (23 kB)
# Downloading langgraph_sdk-0.1.72-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.5 MB/s eta 0:00:00
# Downloading ormsgpack-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 18.1 MB/s eta 0:00:00
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (pyproject.toml) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.14-cp311-cp311-linux_x86_64.whl size=169717 sha256=fdc189189454e3c0ce77a9004ef22cc3fff9079a54deac789a59dd408548cefc
#   Stored in directory: /root/.cache/pip/wheels/9c/5f/df/6fffd2a4353f26dbb0e3672a1baf070c124a1d74a5f9318279
# Successfully built pygraphviz
# Installing collected packages: pygraphviz, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
# Successfully installed langgraph-0.5.1 langgraph-checkpoint-2.1.0 langgraph-prebuilt-0.5.2 langgraph-sdk-0.1.72 ormsgpack-1.10.0 pygraphviz-1.14

# %% [markdown]
# ----

# %%
from google import genai
from typing_extensions import TypedDict

from IPython.display import Image, display

# %%
from google.api_core import retry

is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

genai.models.Models.generate_content = retry.Retry(
    predicate=is_retriable)(genai.models.Models.generate_content)

# %% [markdown]
# 以下のセルを実行するには、シークレットの "GOOGLE_API_KEY" にAPIキーを保存しておく必要があります。
# GeminiのAPIキーは [Google AI Studio](https://aistudio.google.com/) の Get API Key から取得できます。

# %%
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)

def gemini_reply(prompt: str) -> str:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt)
    return response.text

# %%
from langgraph.graph import StateGraph
import re
import json

# %%
# ゲームの状態
class ShiritoriState(TypedDict):
    history: list[str]
    input_word: str
    last_word: str
    user_turn: bool
    user_win: bool
    game_over: bool # ゲームが終了したかどうか

# %%
# ユーザー入力ステップ
def user_input_step(state: ShiritoriState):
    word = input("あなたの単語（終了（投了）は空のままエンター）: ").strip()
    state["input_word"] = word
    state["user_turn"] = True
    return state

# llm応答ステップ
def llm_step(state: ShiritoriState):
    prompt = f"""以下の条件に従って、しりとりの単語を1つ出してください。
- 前の単語: {state['last_word']}
- 使用済み単語: {', '.join(state['history'])}
- 「ん」で終わらないこと
- 再使用禁止

単語だけを返してください。"""

    reply = gemini_reply(prompt)
    word = re.findall(r'\w+', reply)[0]  # 最初の単語を取得
    print(f"Geminiの単語: {word}")
    state["input_word"] = word
    state["user_turn"] = False
    return state

def routing_check_user_input(state: ShiritoriState):
    if state["input_word"] == "":
        return "empty"
    return "exist"

# %%
# ===== 「ん」チェック =====

def n_end(state: ShiritoriState):
    """最後の単語が「ん」で終わった場合の処理"""
    print(f"'{state['input_word']}' は「ん」で終わったためゲームオーバーです。")
    return state

# ----- ルールベース -----

def check_n_rule(state: ShiritoriState):
    """最後の文字が「ん」かどうかをチェックする"""
    return state

def routing_check_n_rule(state: ShiritoriState):
    last_char = state["input_word"][-1]
    print(f"routing_check_n: last_char={last_char}")
    if last_char == "ん" or last_char == "ン":
        return "NG"
    else:
        return "OK"

# ----- LLM -----

def check_n_llm(state: ShiritoriState):
    return state

def routing_check_n_llm(state: ShiritoriState):
    prompt = f"""しりとりにおいて、今回の単語が「ん」で終わっているかどうかを判定してください。

【ルール】
- カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
- たとえば「饂飩」などは読み方が「うどん」なので「ん」で終わっています。

【今回の単語】：{state['input_word']}

【出力フォーマット】
次のJSON形式で出力してください：

{{
  "n_end": true,  // 「ん」で終わっていれば true,「ん」で終わっていなければ false
  "reason": "ここに簡潔な理由を記述"
}}

出力例：
{{
  "n_end": true,
  "reason": "今回の単語は「公園」で読み方が「こうえん」で「ん」で終わっています。"
}}

{{
  "n_end": false,
  "reason": "今回の単語は「後悔」で読み方が「こうかい」で「ん」で終わっていません。"
}}

```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
"""

    print(f"prompt : {prompt}")
    print("========================================")
    reply = gemini_reply(prompt)
    print(f"reply : {reply}")
    print("========================================")
    json_match = re.search(r'\{[\s\S]*\}', reply)
    if not json_match:
        raise ValueError("JSON部分が見つかりませんでした。")

    try:
        json_str = json_match.group(0) # マッチした文字列を抽出
        print(f"json_str : {json_str}")
        print("========================================")
        result = json.loads(json_str)
        if not result["n_end"]:
            return "OK"
        else:
            print(f"{result=}")
            reason = result["reason"]
            print(f"NG : {reason}")
            return "NG"
    except json.JSONDecodeError as e:
        print(f"JSONパースエラー: {e}")
        return "NG"

# %%
# ===== 文章入力されていないかチェック =====

def check_sentence_llm(state: ShiritoriState):
    return state

def routing_check_sentence(state: ShiritoriState):
    prompt = f"""次の日本語の入力が「単語」か「文章」かを判定してください。

【入力】：
{state['input_word']}

【ルール】
- ひとつの名詞や単語であれば「単語」とします。
- 動詞や助詞が複数含まれていたり、主語・述語など文の構造がある場合は「文章」とします。

【出力フォーマット】
次のJSON形式で出力してください：
{{
  "is_sentence": true, // 文章ならtrue、単語ならfalse
  "reason": "判定理由"
}}

出力例：
{{
  "is_sentencez": false,
  "reason": "「幕の内弁当」は単語"
}}

{{
  "is_sentencez": false,
  "reason": "「田中さんの車」は文章"
}}

```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
"""

    print(f"prompt : {prompt}")
    print("========================================")
    reply = gemini_reply(prompt)
    print(f"reply : {reply}")
    print("========================================")
    json_match = re.search(r'\{[\s\S]*\}', reply)
    if not json_match:
        print("文章判定に失敗。入力はNGとみなします。")
        return "NG"
    try:
        result = json.loads(json_match.group(0))
        if result["is_sentence"]:
            print("NG（文章と判定）:", result["reason"])
            return "NG"
        else:
            return "OK"
    except Exception as e:
        print(f"JSON decode error in sentence check: {e}")
        return "NG"

def input_is_sentence(state: ShiritoriState):
    print("入力は文章です")
    return state

# %%
# ===== 履歴チェック =====

def check_history(state: ShiritoriState):
    return state

def routing_check_history(state: ShiritoriState):
    if state["input_word"] in state["history"]:
        return "exist_history"
    return "check_tail_head_rule"

def exist_history(state: ShiritoriState):
    print("すでに使われた単語を出しました")
    return state

# %%
# ===== 末尾と頭のチェック =====

def tail_head_unmatch(state: ShiritoriState):
    print("末尾と頭が一致しません")
    return state

# ----- ルールベース -----

def check_tail_head_rule(state: ShiritoriState):
    return state

def routing_check_tail_head_rule(state: ShiritoriState):
    print(f"routing_check_tail_head : {state=}")
    if len(state["history"]) == 0:
        print("最初の順番 : turn_change")
        return "OK"

    last_word_tail = state["last_word"][-1]
    input_word_head = state["input_word"][0]
    print(f"{last_word_tail=}, {input_word_head=}")

    if state["last_word"][-1] != state["input_word"][0]:
        print("check_tail_head_llm")
        return "NG"
    print("turn_change")
    return "OK"

# ----- LLM -----

def check_tail_head_llm(state: ShiritoriState):
    return state

def routing_check_tail_head_llm(state: ShiritoriState):
    prompt = f"""しりとりにおいて、前の単語と今回の単語が正しくつながっているかを判定してください。

【ルール】
- 単語の最初の文字は、前の単語の最後の文字と一致している必要があります。
- 前の単語が「ー」で終わる場合は、その直前の文字を最後とみなします。
- 「っ」「ゃ」「ょ」などは、小文字と大文字を同一視してよいです。
- カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
- たとえば「らっこ」→「コップ」などは有効。

【前の単語】：{state['last_word']}
【今回の単語】：{state['input_word']}

【出力フォーマット】
次のJSON形式で出力してください：

{{
  "valid_connection": true,  // または false
  "reason": "ここに簡潔な理由を記述"
}}

出力例：
{{
  "valid_connection": false,
  "reason": "前の単語は「りんご」で、最後の文字が「ご」なのに、今回の単語は「さかな」でつながっていません。"
}}

{{
  "valid_connection": true,
  "reason": "前の単語は「つみき」で、最後の文字が「き」であり、今回の単語は「菊（きく）」でつながっています。"
}}

```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
"""

    print(f"prompt : {prompt}")
    print("========================================")
    reply = gemini_reply(prompt)
    print(f"reply : {reply}")
    print("========================================")
    json_match = re.search(r'\{[\s\S]*\}', reply)
    if not json_match:
        raise ValueError("JSON部分が見つかりませんでした。")

    try:
        json_str = json_match.group(0) # マッチした文字列を抽出
        print(f"json_str : {json_str}")
        print("========================================")
        result = json.loads(json_str)
        if result["valid_connection"]:
            return "OK"
        else:
            print(f"{result=}")
            reason = result["reason"]
            print(f"NG : {reason}")
            return "NG"
    except json.JSONDecodeError as e:
        print(f"JSONパースエラー: {e}")
        return "NG"

# %%
# ===== 手番変更処理 =====

def turn_change(state: ShiritoriState):
    word = state["input_word"]
    state["history"].append(word)
    state["last_word"] = word
    state["input_word"] = ""
    return state

# %%
# ===== 次プレイヤーへの遷移 =====

def routing_next_player(state: ShiritoriState):
    if state["user_turn"]:
        return "llm"
    return "user"

# %%
# ===== 降参 =====

def surrender(state: ShiritoriState):
    print("投了")
    return state

# %%
# ===== 勝敗表示 =====

def routing_win_lose(state: ShiritoriState):
    if state["user_turn"]:
        return "user"
    return "llm"

def lose_user(state: ShiritoriState):
    print("あなたの負けです")
    return {"user_win": False, "game_over": True}

def win_user(state: ShiritoriState):
    print("あなたの勝ちです")
    return {"user_win": True, "game_over": True}

# %%
# ===== 次のターン =====

def next_user_input(state: ShiritoriState):
    return state

# %%
# LangGraphのグラフ構築
builder = StateGraph(ShiritoriState)

builder.add_node("user_input", user_input_step)
builder.add_node("llm_response", llm_step)

builder.add_node("check_sentence_llm", check_sentence_llm)
builder.add_node("input_is_sentence", input_is_sentence)

builder.add_node("check_n_rule", check_n_rule)
builder.add_node("check_n_llm", check_n_llm)
builder.add_node("n_end", n_end)

builder.add_node("check_history", check_history)
builder.add_node("exist_history", exist_history)

builder.add_node("check_tail_head_rule", check_tail_head_rule)
builder.add_node("check_tail_head_llm", check_tail_head_llm)
builder.add_node("tail_head_unmatch", tail_head_unmatch)

builder.add_node("turn_change", turn_change)
builder.add_node("surrender", surrender)
builder.add_node("lose", lose_user)
builder.add_node("win", win_user)
builder.add_node("next_user_input", next_user_input)

builder.set_entry_point("user_input")
builder.set_finish_point("lose")
builder.set_finish_point("win")
builder.set_finish_point("next_user_input")

builder.add_conditional_edges(
    source="user_input",
    path=routing_check_user_input,
    path_map={"empty": "surrender", "exist": "check_sentence_llm"},
)

builder.add_conditional_edges(
    source="check_sentence_llm",
    path=routing_check_sentence,
    path_map={"NG": "input_is_sentence", "OK": "check_n_rule"},
)

builder.add_conditional_edges(
    source="check_n_rule",
    path=routing_check_n_rule,
    path_map={"NG": "n_end", "OK": "check_n_llm"},
)
builder.add_conditional_edges(
    source="check_n_llm",
    path=routing_check_n_llm,
    path_map={"NG": "n_end", "OK": "check_history"},
)
builder.add_conditional_edges(
    source="check_history",
    path=routing_check_history,
    path_map={"exist_history": "exist_history", "check_tail_head_rule": "check_tail_head_rule"},
)
builder.add_conditional_edges(
    source="check_tail_head_rule",
    path=routing_check_tail_head_rule,
    path_map={"NG": "check_tail_head_llm", "OK": "turn_change"},
)
builder.add_conditional_edges(
    source="check_tail_head_llm",
    path=routing_check_tail_head_llm,
    path_map={"NG": "tail_head_unmatch", "OK": "turn_change"},
)

builder.add_conditional_edges(
    source="input_is_sentence",
    path=routing_win_lose,
    path_map={"user": "lose", "llm": "win"},
)
builder.add_conditional_edges(
    source="n_end",
    path=routing_win_lose,
    path_map={"user": "lose", "llm": "win"},
)
builder.add_conditional_edges(
    source="exist_history",
    path=routing_win_lose,
    path_map={"user": "lose", "llm": "win"},
)
builder.add_conditional_edges(
    source="tail_head_unmatch",
    path=routing_win_lose,
    path_map={"user": "lose", "llm": "win"},
)

builder.add_conditional_edges(
    source="turn_change",
    path=routing_next_player,
    path_map={"llm": "llm_response", "user": "next_user_input"},
)

builder.add_edge("llm_response", "check_sentence_llm")

builder.add_edge("surrender", "lose")

graph = builder.compile()

# %%
mermaid_str = graph.get_graph().draw_mermaid()
print(mermaid_str)
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	user_input(user_input)
# 	llm_response(llm_response)
# 	check_sentence_llm(check_sentence_llm)
# 	input_is_sentence(input_is_sentence)
# 	check_n_rule(check_n_rule)
# 	check_n_llm(check_n_llm)
# 	n_end(n_end)
# 	check_history(check_history)
# 	exist_history(exist_history)
# 	check_tail_head_rule(check_tail_head_rule)
# 	check_tail_head_llm(check_tail_head_llm)
# 	tail_head_unmatch(tail_head_unmatch)
# 	turn_change(turn_change)
# 	surrender(surrender)
# 	lose(lose)
# 	win(win)
# 	next_user_input(next_user_input)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> user_input;
# 	check_history -.-> check_tail_head_rule;
# 	check_history -.-> exist_history;
# 	check_n_llm -. &nbsp;OK&nbsp; .-> check_history;
# 	check_n_llm -. &nbsp;NG&nbsp; .-> n_end;
# 	check_n_rule -. &nbsp;OK&nbsp; .-> check_n_llm;
# 	check_n_rule -. &nbsp;NG&nbsp; .-> n_end;
# 	check_sentence_llm -. &nbsp;OK&nbsp; .-> check_n_rule;
# 	check_sentence_llm -. &nbsp;NG&nbsp; .-> input_is_sentence;
# 	check_tail_head_llm -. &nbsp;NG&nbsp; .-> tail_head_unmatch;
# 	check_tail_head_llm -. &nbsp;OK&nbsp; .-> turn_change;
# 	check_tail_head_rule -. &nbsp;NG&nbsp; .-> check_tail_head_llm;
# 	check_tail_head_rule -. &nbsp;OK&nbsp; .-> turn_change;
# 	exist_history -. &nbsp;user&nbsp; .-> lose;
# 	exist_history -. &nbsp;llm&nbsp; .-> win;
# 	input_is_sentence -. &nbsp;user&nbsp; .-> lose;
# 	input_is_sentence -. &nbsp;llm&nbsp; .-> win;
# 	llm_response --> check_sentence_llm;
# 	n_end -. &nbsp;user&nbsp; .-> lose;
# 	n_end -. &nbsp;llm&nbsp; .-> win;
# 	surrender --> lose;
# 	tail_head_unmatch -. &nbsp;user&nbsp; .-> lose;
# 	tail_head_unmatch -. &nbsp;llm&nbsp; .-> win;
# 	turn_change -. &nbsp;llm&nbsp; .-> llm_response;
# 	turn_change -. &nbsp;user&nbsp; .-> next_user_input;
# 	user_input -. &nbsp;exist&nbsp; .-> check_sentence_llm;
# 	user_input -. &nbsp;empty&nbsp; .-> surrender;
# 	lose --> __end__;
# 	next_user_input --> __end__;
# 	win --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"グラフの描画中にエラーが発生しました: {e}") # 描画中に発生したエラーを出力する
    pass

# %%
try:
    display(Image(graph.get_graph().draw_png()))
except Exception as e:
    print(f"グラフの描画中にエラーが発生しました: {e}") # 描画中に発生したエラーを出力する
    pass

# %%
# 初期状態
state = ShiritoriState({"history": [], "last_word": "", "game_over": False})
config = {"recursion_limit": 20}

while not state["game_over"]:
    state = graph.invoke(state, config=config, debug=True)
# Out:
# [values] {'history': [], 'last_word': '', 'game_over': False}
# あなたの単語（終了（投了）は空のままエンター）: りんご
# [updates] {'user_input': {'history': [], 'last_word': '', 'game_over': False, 'input_word': 'りんご', 'user_turn': True}}
# [values] {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# prompt : 次の日本語の入力が「単語」か「文章」かを判定してください。
#
# 【入力】：
# りんご
#
# 【ルール】
# - ひとつの名詞や単語であれば「単語」とします。
# - 動詞や助詞が複数含まれていたり、主語・述語など文の構造がある場合は「文章」とします。
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
# {
#   "is_sentence": true, // 文章ならtrue、単語ならfalse
#   "reason": "判定理由"
# }
#
# 出力例：
# {
#   "is_sentencez": false,
#   "reason": "「幕の内弁当」は単語"
# }
#
# {
#   "is_sentencez": false,
#   "reason": "「田中さんの車」は文章"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "is_sentence": false,
#   "reason": "「りんご」は単一の名詞であるため単語と判定します。"
# }
# ```
# ========================================
# [updates] {'check_sentence_llm': {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}}
# [values] {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# routing_check_n: last_char=ご
# [updates] {'check_n_rule': {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}}
# [values] {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# prompt : しりとりにおいて、今回の単語が「ん」で終わっているかどうかを判定してください。
#
# 【ルール】
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「饂飩」などは読み方が「うどん」なので「ん」で終わっています。
#
# 【今回の単語】：りんご
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "n_end": true,  // 「ん」で終わっていれば true,「ん」で終わっていなければ false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "n_end": true,
#   "reason": "今回の単語は「公園」で読み方が「こうえん」で「ん」で終わっています。"
# }
#
# {
#   "n_end": false,
#   "reason": "今回の単語は「後悔」で読み方が「こうかい」で「ん」で終わっていません。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "n_end": false,
#   "reason": "今回の単語は「りんご」で読み方が「りんご」で「ん」で終わっていません。"
# }
# ```
# ========================================
# json_str : {
#   "n_end": false,
#   "reason": "今回の単語は「りんご」で読み方が「りんご」で「ん」で終わっていません。"
# }
# ========================================
# [updates] {'check_n_llm': {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}}
# [values] {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# [updates] {'check_history': {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}}
# [values] {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# routing_check_tail_head : state={'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# 最初の順番 : turn_change
# [updates] {'check_tail_head_rule': {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}}
# [values] {'history': [], 'input_word': 'りんご', 'last_word': '', 'user_turn': True, 'game_over': False}
# [updates] {'turn_change': {'history': ['りんご'], 'input_word': '', 'last_word': 'りんご', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': '', 'last_word': 'りんご', 'user_turn': True, 'game_over': False}
# Geminiの単語: ゴリラ
# [updates] {'llm_response': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# prompt : 次の日本語の入力が「単語」か「文章」かを判定してください。
#
# 【入力】：
# ゴリラ
#
# 【ルール】
# - ひとつの名詞や単語であれば「単語」とします。
# - 動詞や助詞が複数含まれていたり、主語・述語など文の構造がある場合は「文章」とします。
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
# {
#   "is_sentence": true, // 文章ならtrue、単語ならfalse
#   "reason": "判定理由"
# }
#
# 出力例：
# {
#   "is_sentencez": false,
#   "reason": "「幕の内弁当」は単語"
# }
#
# {
#   "is_sentencez": false,
#   "reason": "「田中さんの車」は文章"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "is_sentence": false,
#   "reason": "「ゴリラ」は単一の名詞であり、動詞や助詞を含まず、文の構造を持たないため単語です。"
# }
# ```
# ========================================
# [updates] {'check_sentence_llm': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# routing_check_n: last_char=ラ
# [updates] {'check_n_rule': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# prompt : しりとりにおいて、今回の単語が「ん」で終わっているかどうかを判定してください。
#
# 【ルール】
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「饂飩」などは読み方が「うどん」なので「ん」で終わっています。
#
# 【今回の単語】：ゴリラ
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "n_end": true,  // 「ん」で終わっていれば true,「ん」で終わっていなければ false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "n_end": true,
#   "reason": "今回の単語は「公園」で読み方が「こうえん」で「ん」で終わっています。"
# }
#
# {
#   "n_end": false,
#   "reason": "今回の単語は「後悔」で読み方が「こうかい」で「ん」で終わっていません。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "n_end": false,
#   "reason": "今回の単語は「ゴリラ」で読み方が「ゴリラ」で「ん」で終わっていません。"
# }
# ```
# ========================================
# json_str : {
#   "n_end": false,
#   "reason": "今回の単語は「ゴリラ」で読み方が「ゴリラ」で「ん」で終わっていません。"
# }
# ========================================
# [updates] {'check_n_llm': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# [updates] {'check_history': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# routing_check_tail_head : state={'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# last_word_tail='ご', input_word_head='ゴ'
# check_tail_head_llm
# [updates] {'check_tail_head_rule': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# prompt : しりとりにおいて、前の単語と今回の単語が正しくつながっているかを判定してください。
#
# 【ルール】
# - 単語の最初の文字は、前の単語の最後の文字と一致している必要があります。
# - 前の単語が「ー」で終わる場合は、その直前の文字を最後とみなします。
# - 「っ」「ゃ」「ょ」などは、小文字と大文字を同一視してよいです。
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「らっこ」→「コップ」などは有効。
#
# 【前の単語】：りんご
# 【今回の単語】：ゴリラ
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "valid_connection": true,  // または false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "valid_connection": false,
#   "reason": "前の単語は「りんご」で、最後の文字が「ご」なのに、今回の単語は「さかな」でつながっていません。"
# }
#
# {
#   "valid_connection": true,
#   "reason": "前の単語は「つみき」で、最後の文字が「き」であり、今回の単語は「菊（きく）」でつながっています。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "valid_connection": true,
#   "reason": "前の単語は「りんご」で、最後の文字が「ご」であり、今回の単語は「ゴリラ」でつながっています。"
# }
# ```
# ========================================
# json_str : {
#   "valid_connection": true,
#   "reason": "前の単語は「りんご」で、最後の文字が「ご」であり、今回の単語は「ゴリラ」でつながっています。"
# }
# ========================================
# [updates] {'check_tail_head_llm': {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご'], 'input_word': 'ゴリラ', 'last_word': 'りんご', 'user_turn': False, 'game_over': False}
# [updates] {'turn_change': {'history': ['りんご', 'ゴリラ'], 'input_word': '', 'last_word': 'ゴリラ', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '', 'last_word': 'ゴリラ', 'user_turn': False, 'game_over': False}
# [updates] {'next_user_input': {'history': ['りんご', 'ゴリラ'], 'input_word': '', 'last_word': 'ゴリラ', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '', 'last_word': 'ゴリラ', 'user_turn': False, 'game_over': False}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '', 'last_word': 'ゴリラ', 'user_turn': False, 'game_over': False}
# あなたの単語（終了（投了）は空のままエンター）: 駱駝
# [updates] {'user_input': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# prompt : 次の日本語の入力が「単語」か「文章」かを判定してください。
#
# 【入力】：
# 駱駝
#
# 【ルール】
# - ひとつの名詞や単語であれば「単語」とします。
# - 動詞や助詞が複数含まれていたり、主語・述語など文の構造がある場合は「文章」とします。
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
# {
#   "is_sentence": true, // 文章ならtrue、単語ならfalse
#   "reason": "判定理由"
# }
#
# 出力例：
# {
#   "is_sentencez": false,
#   "reason": "「幕の内弁当」は単語"
# }
#
# {
#   "is_sentencez": false,
#   "reason": "「田中さんの車」は文章"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "is_sentence": false,
#   "reason": "「駱駝」は名詞であり、単一の語であるため単語と判定します。"
# }
# ```
# ========================================
# [updates] {'check_sentence_llm': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# routing_check_n: last_char=駝
# [updates] {'check_n_rule': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# prompt : しりとりにおいて、今回の単語が「ん」で終わっているかどうかを判定してください。
#
# 【ルール】
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「饂飩」などは読み方が「うどん」なので「ん」で終わっています。
#
# 【今回の単語】：駱駝
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "n_end": true,  // 「ん」で終わっていれば true,「ん」で終わっていなければ false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "n_end": true,
#   "reason": "今回の単語は「公園」で読み方が「こうえん」で「ん」で終わっています。"
# }
#
# {
#   "n_end": false,
#   "reason": "今回の単語は「後悔」で読み方が「こうかい」で「ん」で終わっていません。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : {
#   "n_end": false,
#   "reason": "今回の単語は「駱駝」で読み方が「ラクダ」で「ん」で終わっていません。"
# }
# ========================================
# json_str : {
#   "n_end": false,
#   "reason": "今回の単語は「駱駝」で読み方が「ラクダ」で「ん」で終わっていません。"
# }
# ========================================
# [updates] {'check_n_llm': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# [updates] {'check_history': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# routing_check_tail_head : state={'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# last_word_tail='ラ', input_word_head='駱'
# check_tail_head_llm
# [updates] {'check_tail_head_rule': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# prompt : しりとりにおいて、前の単語と今回の単語が正しくつながっているかを判定してください。
#
# 【ルール】
# - 単語の最初の文字は、前の単語の最後の文字と一致している必要があります。
# - 前の単語が「ー」で終わる場合は、その直前の文字を最後とみなします。
# - 「っ」「ゃ」「ょ」などは、小文字と大文字を同一視してよいです。
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「らっこ」→「コップ」などは有効。
#
# 【前の単語】：ゴリラ
# 【今回の単語】：駱駝
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "valid_connection": true,  // または false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "valid_connection": false,
#   "reason": "前の単語は「りんご」で、最後の文字が「ご」なのに、今回の単語は「さかな」でつながっていません。"
# }
#
# {
#   "valid_connection": true,
#   "reason": "前の単語は「つみき」で、最後の文字が「き」であり、今回の単語は「菊（きく）」でつながっています。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "valid_connection": true,
#   "reason": "前の単語「ゴリラ」の読みの最後の文字は「ら」であり、今回の単語「駱駝（らくだ）」の読みの最初の文字も「ら」でつながっています。"
# }
# ```
# ========================================
# json_str : {
#   "valid_connection": true,
#   "reason": "前の単語「ゴリラ」の読みの最後の文字は「ら」であり、今回の単語「駱駝（らくだ）」の読みの最初の文字も「ら」でつながっています。"
# }
# ========================================
# [updates] {'check_tail_head_llm': {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ'], 'input_word': '駱駝', 'last_word': 'ゴリラ', 'user_turn': True, 'game_over': False}
# [updates] {'turn_change': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': '', 'last_word': '駱駝', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': '', 'last_word': '駱駝', 'user_turn': True, 'game_over': False}
# Geminiの単語: だちょう
# [updates] {'llm_response': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# prompt : 次の日本語の入力が「単語」か「文章」かを判定してください。
#
# 【入力】：
# だちょう
#
# 【ルール】
# - ひとつの名詞や単語であれば「単語」とします。
# - 動詞や助詞が複数含まれていたり、主語・述語など文の構造がある場合は「文章」とします。
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
# {
#   "is_sentence": true, // 文章ならtrue、単語ならfalse
#   "reason": "判定理由"
# }
#
# 出力例：
# {
#   "is_sentencez": false,
#   "reason": "「幕の内弁当」は単語"
# }
#
# {
#   "is_sentencez": false,
#   "reason": "「田中さんの車」は文章"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "is_sentence": false,
#   "reason": "「だちょう」は単一の名詞であり、文の構造を持たないため、単語です。"
# }
# ```
# ========================================
# [updates] {'check_sentence_llm': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# routing_check_n: last_char=う
# [updates] {'check_n_rule': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# prompt : しりとりにおいて、今回の単語が「ん」で終わっているかどうかを判定してください。
#
# 【ルール】
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「饂飩」などは読み方が「うどん」なので「ん」で終わっています。
#
# 【今回の単語】：だちょう
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "n_end": true,  // 「ん」で終わっていれば true,「ん」で終わっていなければ false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "n_end": true,
#   "reason": "今回の単語は「公園」で読み方が「こうえん」で「ん」で終わっています。"
# }
#
# {
#   "n_end": false,
#   "reason": "今回の単語は「後悔」で読み方が「こうかい」で「ん」で終わっていません。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : {
#   "n_end": false,
#   "reason": "今回の単語は「だちょう」で読み方が「だちょう」で「う」で終わっており、「ん」で終わっていません。"
# }
# ========================================
# json_str : {
#   "n_end": false,
#   "reason": "今回の単語は「だちょう」で読み方が「だちょう」で「う」で終わっており、「ん」で終わっていません。"
# }
# ========================================
# [updates] {'check_n_llm': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# [updates] {'check_history': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# routing_check_tail_head : state={'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# last_word_tail='駝', input_word_head='だ'
# check_tail_head_llm
# [updates] {'check_tail_head_rule': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# prompt : しりとりにおいて、前の単語と今回の単語が正しくつながっているかを判定してください。
#
# 【ルール】
# - 単語の最初の文字は、前の単語の最後の文字と一致している必要があります。
# - 前の単語が「ー」で終わる場合は、その直前の文字を最後とみなします。
# - 「っ」「ゃ」「ょ」などは、小文字と大文字を同一視してよいです。
# - カタカナ、ひらがな、漢字といった表記は無視して読み方の最後の文字で判断してください。
# - たとえば「らっこ」→「コップ」などは有効。
#
# 【前の単語】：駱駝
# 【今回の単語】：だちょう
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
#
# {
#   "valid_connection": true,  // または false
#   "reason": "ここに簡潔な理由を記述"
# }
#
# 出力例：
# {
#   "valid_connection": false,
#   "reason": "前の単語は「りんご」で、最後の文字が「ご」なのに、今回の単語は「さかな」でつながっていません。"
# }
#
# {
#   "valid_connection": true,
#   "reason": "前の単語は「つみき」で、最後の文字が「き」であり、今回の単語は「菊（きく）」でつながっています。"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "valid_connection": true,
#   "reason": "前の単語は「駱駝（らくだ）」で、最後の文字が「だ」であり、今回の単語は「だちょう」でつながっています。"
# }
# ```
# ========================================
# json_str : {
#   "valid_connection": true,
#   "reason": "前の単語は「駱駝（らくだ）」で、最後の文字が「だ」であり、今回の単語は「だちょう」でつながっています。"
# }
# ========================================
# [updates] {'check_tail_head_llm': {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝'], 'input_word': 'だちょう', 'last_word': '駱駝', 'user_turn': False, 'game_over': False}
# [updates] {'turn_change': {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '', 'last_word': 'だちょう', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '', 'last_word': 'だちょう', 'user_turn': False, 'game_over': False}
# [updates] {'next_user_input': {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '', 'last_word': 'だちょう', 'user_turn': False, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '', 'last_word': 'だちょう', 'user_turn': False, 'game_over': False}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '', 'last_word': 'だちょう', 'user_turn': False, 'game_over': False}
# あなたの単語（終了（投了）は空のままエンター）: 海のような青
# [updates] {'user_input': {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'game_over': False}
# prompt : 次の日本語の入力が「単語」か「文章」かを判定してください。
#
# 【入力】：
# 海のような青
#
# 【ルール】
# - ひとつの名詞や単語であれば「単語」とします。
# - 動詞や助詞が複数含まれていたり、主語・述語など文の構造がある場合は「文章」とします。
#
# 【出力フォーマット】
# 次のJSON形式で出力してください：
# {
#   "is_sentence": true, // 文章ならtrue、単語ならfalse
#   "reason": "判定理由"
# }
#
# 出力例：
# {
#   "is_sentencez": false,
#   "reason": "「幕の内弁当」は単語"
# }
#
# {
#   "is_sentencez": false,
#   "reason": "「田中さんの車」は文章"
# }
#
# ```json 〜 ``` のようなJSONとしてパースできない装飾を出力しないでください。
#
# ========================================
# reply : ```json
# {
#   "is_sentence": true,
#   "reason": "「海のような青」は、「の」という助詞が含まれており、「海のような」という句が「青」という名詞を修飾する構造になっているため、単一の単語ではなく、複数の単語が結合した文章と判定されます。出力例の「田中さんの車」が文章と判断されるのと同様の理由です。"
# }
# ```
# ========================================
# NG（文章と判定）: 「海のような青」は、「の」という助詞が含まれており、「海のような」という句が「青」という名詞を修飾する構造になっているため、単一の単語ではなく、複数の単語が結合した文章と判定されます。出力例の「田中さんの車」が文章と判断されるのと同様の理由です。
# [updates] {'check_sentence_llm': {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'game_over': False}
# 入力は文章です
# [updates] {'input_is_sentence': {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'game_over': False}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'game_over': False}
# あなたの負けです
# [updates] {'lose': {'user_win': False, 'game_over': True}}
# [values] {'history': ['りんご', 'ゴリラ', '駱駝', 'だちょう'], 'input_word': '海のような青', 'last_word': 'だちょう', 'user_turn': True, 'user_win': False, 'game_over': True}
